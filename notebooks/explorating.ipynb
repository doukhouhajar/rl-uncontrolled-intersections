# %% [markdown]
# # Training Analysis

# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

import numpy as np
import matplotlib.pyplot as plt
from src.algorithms.cql_trainer import train_cql
from src.environments.wrapper import AutoencoderWrapper

# %% [markdown]
# ## Load Training Results
#
# Load and visualize training metrics from logs.

# %%
# Example: Load training logs
# logs_path = '../results/logs/training_log.csv'
# logs = pd.read_csv(logs_path)
# plt.plot(logs['epoch'], logs['loss'])
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Training Loss')
# plt.show()
